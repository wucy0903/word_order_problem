# %%
import csv 
import requests
import json
import monpa
with open ('./CJX_data.csv', 'r' , encoding = 'utf-8') as wf:
    rows = csv.reader(wf)
    res = list()
    for sentence in rows:
        print (sentence[0])
        #html = requests.get('http://192.168.10.216/jieba/cut/api/v1.0/'+ sentence[1]).text
        #cut_res = json.loads(html)['cont']
        #print (cut_res)
        cut_res = monpa.pseg(sentence[1])
        res.append(cut_res)
        print (res)
# Out:
# id
# [[['sentence', 'FW']]]
# 1
# [[['sentence', 'FW']], [['第二', 'Neu'], ['，', 'COMMACATEGORY'], ['人們', 'Na'], ['用', 'P'], ['化學', 'Na'], ['物質', 'Na'], ['時間', 'Na'], ['長', 'VH'], ['，', 'COMMACATEGORY'], ['自然', 'Na'], ['{', 'PARENTHESISCATEGORY'], ['CJX', 'FW'], ['}', 'PARENTHESISCATEGORY'], ['也', 'D'], ['會', 'D'], ['污染', 'VC'], ['。', 'PERIODCATEGORY']]]
# 2
# [[['sentence', 'FW']], [['第二', 'Neu'], ['，', 'COMMACATEGORY'], ['人們', 'Na'], ['用', 'P'], ['化學', 'Na'], ['物質', 'Na'], ['時間', 'Na'], ['長', 'VH'], ['，', 'COMMACATEGORY'], ['自然', 'Na'], ['{', 'PARENTHESISCATEGORY'], ['CJX', 'FW'], ['}', 'PARENTHESISCATEGORY'], ['也', 'D'], ['會', 'D'], ['污染', 'VC'], ['。', 'PERIODCATEGORY']], [['可是', 'Cbb'], ['弊端', 'Na'], ['{', 'PARENTHESISCATEGORY'], ['CJX', 'FW'], ['}', 'PARENTHESISCATEGORY'], ['也', 'D'], ['帶來', 'VC'], ['。', 'PERIODCATEGORY']]]
# 3
# ...
